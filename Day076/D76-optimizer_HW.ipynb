# %% [markdown]
# # 作業重點:
#
# (1)以, Adam, 為例, 調整 batch_size, epoch , 觀察accurancy, loss 的變化
#
# (2)以同一模型, 分別驗證 SGD, Adam, Rmsprop 的 accurancy

# %% [markdown]
# # 作業目標:
#
#     取得各種優化器的運算結果

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
from keras import optimizers

# %%
#Blas GEMM launch failed , 避免動態分配GPU / CPU, 出現問題
import tensorflow as tf
# gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
'''
   宣告並設定
   batch_size：對總的樣本數進行分組，每組包含的樣本數量
   epochs ：訓練次數
   
''' 

batch_size = 32
num_classes = 10
epochs = 20
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_names = [
                'keras_cifar10_trained_model_sgd.h5',
                'keras_cifar10_trained_model_rms.h5',
                'keras_cifar10_trained_model_adam.h5'
             ]

# %%
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
#    第一步：選擇模型, 順序模型是多個網絡層的線性堆疊
 
model = Sequential()

#   第二步：構建網絡層
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense( 10)) # 輸出結果是10個類別，所以維度是10   
model.add(Activation('softmax')) # 最後一層用softmax作為激活函數

# %%
# 模型建立完成後，統計參數總量
print("Total Parameters：%d" % model.count_params())
# Out:
# Total Parameters：1250858

# %%
# 輸出模型摘要資訊
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
#第三步編譯
'''
 SGD(隨機梯度下降) - Arguments
lr: float >= 0. Learning rate.
momentum: float >= 0. Parameter that accelerates SGD in the relevant direction and dampens oscillations.
decay: float >= 0. Learning rate decay over each update.
nesterov: boolean. Whether to apply Nesterov momentum.
'''
sgd = optimizers.SGD(lr=0.001, momentum=0.0, decay=0.0, nesterov=False)
'''
RMSprop- Arguments
lr: float >= 0. Learning rate.
rho: float >= 0.
epsilon: float >= 0. Fuzz factor. If None, defaults to K.epsilon().
decay: float >= 0. Learning rate decay over each update.
'''
rms = optimizers.RMSprop(lr=0.001)
'''
Example:
opt = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

'''
adam = optimizers.Adam()
opts = [sgd, rms, adam]

# %%
# 資料正規化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
# 是否要做資料處理
history = []
models = []
for opt in opts:
    model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    if not data_augmentation:
        print('Not using data augmentation.')
        history.append(model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  shuffle=True))
        models.append(model)
        model=keras.models.clone_model(model)
    else:
        print('Using real-time data augmentation.')
        print('')

        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)
        history.append(model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  shuffle=True))
        models.append(model)
        model=keras.models.clone_model(model)

'''
   第四步：訓練
   .fit的一些參數
   batch_size：對總的樣本數進行分組，每組包含的樣本數量
   epochs ：訓練次數
   shuffle：是否把數據隨機打亂之後再進行訓練
   validation_split：拿出百分之多少用來做交叉驗證
   verbose：屏顯模式 - 0：不輸出, 1：輸出進度, 2：輸出每次的訓練結果
'''
# Out:
# Using real-time data augmentation.
#
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001A9985DD9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001A9985DD9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - ETA: 0s - loss: 2.3021 - accuracy: 0.1110WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001A99975A288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001A99975A288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 177s 113ms/step - loss: 2.3021 - accuracy: 0.1110 - val_loss: 2.2921 - val_accuracy: 0.1479
# Epoch 2/20
# 1563/1563 [==============================] - 164s 105ms/step - loss: 2.2792 - accuracy: 0.1381 - val_loss: 2.2501 - val_accuracy: 0.2190
# Epoch 3/20
# 1563/1563 [==============================] - 162s 103ms/step - loss: 2.1898 - accuracy: 0.1890 - val_loss: 2.0752 - val_accuracy: 0.2576
# Epoch 4/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 2.0724 - accuracy: 0.2255 - val_loss: 2.0092 - val_accuracy: 0.2740
# Epoch 5/20
# 1563/1563 [==============================] - 158s 101ms/step - loss: 2.0294 - accuracy: 0.2493 - val_loss: 1.9675 - val_accuracy: 0.2893
# Epoch 6/20
# 1563/1563 [==============================] - 161s 103ms/step - loss: 1.9994 - accuracy: 0.2645 - val_loss: 1.9363 - val_accuracy: 0.3062
# Epoch 7/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 1.9715 - accuracy: 0.2780 - val_loss: 1.9261 - val_accuracy: 0.3193
# Epoch 8/20
# 1563/1563 [==============================] - 160s 102ms/step - loss: 1.9417 - accuracy: 0.2931 - val_loss: 1.8713 - val_accuracy: 0.3411
# Epoch 9/20
# 1563/1563 [==============================] - 160s 102ms/step - loss: 1.9057 - accuracy: 0.3089 - val_loss: 1.8520 - val_accuracy: 0.3488
# Epoch 10/20
# 1563/1563 [==============================] - 162s 103ms/step - loss: 1.8684 - accuracy: 0.3245 - val_loss: 1.7813 - val_accuracy: 0.3734
# Epoch 11/20
# 1563/1563 [==============================] - 159s 101ms/step - loss: 1.8214 - accuracy: 0.3429 - val_loss: 1.7307 - val_accuracy: 0.3886
# Epoch 12/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 1.7813 - accuracy: 0.3543 - val_loss: 1.6971 - val_accuracy: 0.3946
# Epoch 13/20
# 1563/1563 [==============================] - 162s 104ms/step - loss: 1.7464 - accuracy: 0.3634 - val_loss: 1.6671 - val_accuracy: 0.4082
# Epoch 14/20
# 1563/1563 [==============================] - 170s 109ms/step - loss: 1.7136 - accuracy: 0.3751 - val_loss: 1.6352 - val_accuracy: 0.4114
# Epoch 15/20
# 1563/1563 [==============================] - 160s 103ms/step - loss: 1.6856 - accuracy: 0.3823 - val_loss: 1.6074 - val_accuracy: 0.4213
# Epoch 16/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 1.6612 - accuracy: 0.3941 - val_loss: 1.5727 - val_accuracy: 0.4289
# Epoch 17/20
# 1563/1563 [==============================] - 162s 103ms/step - loss: 1.6389 - accuracy: 0.4037 - val_loss: 1.6357 - val_accuracy: 0.4159
# Epoch 18/20
# 1563/1563 [==============================] - 159s 101ms/step - loss: 1.6170 - accuracy: 0.4109 - val_loss: 1.5426 - val_accuracy: 0.4396
# Epoch 19/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 1.5933 - accuracy: 0.4215 - val_loss: 1.5142 - val_accuracy: 0.4532
# Epoch 20/20
# 1563/1563 [==============================] - 160s 103ms/step - loss: 1.5769 - accuracy: 0.4251 - val_loss: 1.4834 - val_accuracy: 0.4640
# Using real-time data augmentation.
#
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001A998665C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001A998665C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - ETA: 0s - loss: 1.5510 - accuracy: 0.4407WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001A999E770D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001A999E770D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 173s 110ms/step - loss: 1.5510 - accuracy: 0.4407 - val_loss: 1.2010 - val_accuracy: 0.5694
# Epoch 2/20
# 1563/1563 [==============================] - 168s 107ms/step - loss: 1.1790 - accuracy: 0.5865 - val_loss: 1.0861 - val_accuracy: 0.6150
# Epoch 3/20
# 1563/1563 [==============================] - 168s 107ms/step - loss: 1.0375 - accuracy: 0.6396 - val_loss: 0.9133 - val_accuracy: 0.6861
# Epoch 4/20
# 1563/1563 [==============================] - 172s 110ms/step - loss: 0.9943 - accuracy: 0.6615 - val_loss: 0.9639 - val_accuracy: 0.6726
# Epoch 5/20
# 1563/1563 [==============================] - 171s 110ms/step - loss: 0.9957 - accuracy: 0.6677 - val_loss: 0.9155 - val_accuracy: 0.6898
# Epoch 6/20
# 1563/1563 [==============================] - 170s 109ms/step - loss: 1.0045 - accuracy: 0.6658 - val_loss: 1.3225 - val_accuracy: 0.6087
# Epoch 7/20
# 1563/1563 [==============================] - 168s 108ms/step - loss: 1.0338 - accuracy: 0.6580 - val_loss: 1.0204 - val_accuracy: 0.6649
# Epoch 8/20
# 1563/1563 [==============================] - 172s 110ms/step - loss: 1.0487 - accuracy: 0.6555 - val_loss: 1.0934 - val_accuracy: 0.6648
# Epoch 9/20
# 1563/1563 [==============================] - 169s 108ms/step - loss: 1.0767 - accuracy: 0.6493 - val_loss: 0.9730 - val_accuracy: 0.6875
# Epoch 10/20
# 1563/1563 [==============================] - 163s 104ms/step - loss: 1.1101 - accuracy: 0.6400 - val_loss: 1.0037 - val_accuracy: 0.6581
# Epoch 11/20
# 1563/1563 [==============================] - 167s 107ms/step - loss: 1.1442 - accuracy: 0.6300 - val_loss: 1.0643 - val_accuracy: 0.6300
# Epoch 12/20
# 1563/1563 [==============================] - 163s 104ms/step - loss: 1.1778 - accuracy: 0.6197 - val_loss: 0.9496 - val_accuracy: 0.6849
# Epoch 13/20
# 1563/1563 [==============================] - 166s 106ms/step - loss: 1.2122 - accuracy: 0.6139 - val_loss: 1.0979 - val_accuracy: 0.6440
# Epoch 14/20
# 1563/1563 [==============================] - 164s 105ms/step - loss: 1.2493 - accuracy: 0.6018 - val_loss: 1.4415 - val_accuracy: 0.5395
# Epoch 15/20
# 1563/1563 [==============================] - 166s 106ms/step - loss: 1.2658 - accuracy: 0.5961 - val_loss: 1.1737 - val_accuracy: 0.6042
# Epoch 16/20
# 1563/1563 [==============================] - 165s 106ms/step - loss: 1.3117 - accuracy: 0.5824 - val_loss: 1.3412 - val_accuracy: 0.5402
# Epoch 17/20
# 1563/1563 [==============================] - 176s 112ms/step - loss: 1.3645 - accuracy: 0.5659 - val_loss: 1.3893 - val_accuracy: 0.5530
# Epoch 18/20
# 1563/1563 [==============================] - 164s 105ms/step - loss: 1.3859 - accuracy: 0.5568 - val_loss: 1.2003 - val_accuracy: 0.5866
# Epoch 19/20
# 1563/1563 [==============================] - 166s 106ms/step - loss: 1.4030 - accuracy: 0.5476 - val_loss: 1.4173 - val_accuracy: 0.5164
# Epoch 20/20
# 1563/1563 [==============================] - 163s 104ms/step - loss: 1.4529 - accuracy: 0.5312 - val_loss: 1.2387 - val_accuracy: 0.5742
# Using real-time data augmentation.
#
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001A999965A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001A999965A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - ETA: 0s - loss: 1.5087 - accuracy: 0.4518WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001A999B6A168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001A999B6A168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 155s 99ms/step - loss: 1.5087 - accuracy: 0.4518 - val_loss: 1.2118 - val_accuracy: 0.5659
# Epoch 2/20
# 1563/1563 [==============================] - 158s 101ms/step - loss: 1.1168 - accuracy: 0.6040 - val_loss: 0.9339 - val_accuracy: 0.6730
# Epoch 3/20
# 1563/1563 [==============================] - 159s 101ms/step - loss: 0.9731 - accuracy: 0.6556 - val_loss: 0.8764 - val_accuracy: 0.6875
# Epoch 4/20
# 1563/1563 [==============================] - 155s 99ms/step - loss: 0.8987 - accuracy: 0.6852 - val_loss: 0.8628 - val_accuracy: 0.6939
# Epoch 5/20
# 1563/1563 [==============================] - 155s 99ms/step - loss: 0.8367 - accuracy: 0.7058 - val_loss: 0.7547 - val_accuracy: 0.7382
# Epoch 6/20
# 1563/1563 [==============================] - 160s 102ms/step - loss: 0.7861 - accuracy: 0.7215 - val_loss: 0.7452 - val_accuracy: 0.7429
# Epoch 7/20
# 1563/1563 [==============================] - 157s 101ms/step - loss: 0.7548 - accuracy: 0.7342 - val_loss: 0.7491 - val_accuracy: 0.7438
# Epoch 8/20
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.7178 - accuracy: 0.7468 - val_loss: 0.7171 - val_accuracy: 0.7568
# Epoch 9/20
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.6976 - accuracy: 0.7566 - val_loss: 0.6911 - val_accuracy: 0.7624
# Epoch 10/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.6645 - accuracy: 0.7642 - val_loss: 0.6823 - val_accuracy: 0.7615
# Epoch 11/20
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.6531 - accuracy: 0.7709 - val_loss: 0.6636 - val_accuracy: 0.7737
# Epoch 12/20
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.6284 - accuracy: 0.7806 - val_loss: 0.6860 - val_accuracy: 0.7644
# Epoch 13/20
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.6145 - accuracy: 0.7816 - val_loss: 0.6792 - val_accuracy: 0.7683
# Epoch 14/20
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.5927 - accuracy: 0.7907 - val_loss: 0.6642 - val_accuracy: 0.7748
# Epoch 15/20
# 1563/1563 [==============================] - 160s 103ms/step - loss: 0.5822 - accuracy: 0.7976 - val_loss: 0.6918 - val_accuracy: 0.7688
# Epoch 16/20
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.5621 - accuracy: 0.8017 - val_loss: 0.6682 - val_accuracy: 0.7751
# Epoch 17/20
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.5633 - accuracy: 0.7995 - val_loss: 0.6903 - val_accuracy: 0.7639
# Epoch 18/20
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.5445 - accuracy: 0.8071 - val_loss: 0.6741 - val_accuracy: 0.7783
# Epoch 19/20
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.5317 - accuracy: 0.8116 - val_loss: 0.7050 - val_accuracy: 0.7719
# Epoch 20/20
# 1563/1563 [==============================] - 162s 104ms/step - loss: 0.5227 - accuracy: 0.8148 - val_loss: 0.6572 - val_accuracy: 0.7810
# '\n   第四步：訓練\n   .fit的一些參數\n   batch_size：對總的樣本數進行分組，每組包含的樣本數量\n   epochs ：訓練次數\n   shuffle：是否把數據隨機打亂之後再進行訓練\n   validation_split：拿出百分之多少用來做交叉驗證\n   verbose：屏顯模式 - 0：不輸出, 1：輸出進度, 2：輸出每次的訓練結果\n'

# %%
# Save model and weights
for i in range(3):
    if not os.path.isdir(save_dir):
        os.makedirs(save_dir)
    model_path = os.path.join(save_dir, model_names[i])
    models[i].save(model_path)
    print('Saved trained model at %s ' % model_path)

    # Score trained model.
    scores = models[i].evaluate(x_test, y_test, verbose=1)
    print('Test loss:', scores[0])
    print('Test accuracy:', scores[1])
# Out:
# Saved trained model at C:\Users\JoeZhong\Documents\GitHub\3rd-ML100Days\Day076\saved_models\keras_cifar10_trained_model_sgd.h5
# 313/313 [==============================] - 7s 21ms/step - loss: 1.4834 - accuracy: 0.4640
# Test loss: 1.4833500385284424
# Test accuracy: 0.46399998664855957
# Saved trained model at C:\Users\JoeZhong\Documents\GitHub\3rd-ML100Days\Day076\saved_models\keras_cifar10_trained_model_rms.h5
# 313/313 [==============================] - 6s 20ms/step - loss: 1.2387 - accuracy: 0.5742 0s - loss: 1.2406 - accu
# Test loss: 1.2386538982391357
# Test accuracy: 0.5741999745368958
# Saved trained model at C:\Users\JoeZhong\Documents\GitHub\3rd-ML100Days\Day076\saved_models\keras_cifar10_trained_model_adam.h5
# 313/313 [==============================] - 6s 20ms/step - loss: 0.6572 - accuracy: 0.7810
# Test loss: 0.6572362184524536
# Test accuracy: 0.781000018119812

# %%
#    第六步：輸出
import numpy 
for model in models:
    print ( " test set " )
    scores = model.evaluate(x_test,y_test,batch_size=200,verbose= 0)
    print ( "" )
    #print ( " The test loss is %f " % scores)
    print ( " The test loss is %f ", scores)


    result = model.predict(x_test,batch_size=200,verbose= 0)

    result_max = numpy.argmax(result, axis = 1 )
    test_max = numpy.argmax(y_test, axis = 1 )

    result_bool = numpy.equal(result_max, test_max)
    true_num = numpy.sum(result_bool)
# Out:
#  test set
#
#  The test loss is %f  [1.4833500385284424, 0.46399998664855957]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A999CF3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A999CF3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#  test set
#
#  The test loss is %f  [1.2386536598205566, 0.5741999745368958]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A999C8A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A999C8A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#  test set
#
#  The test loss is %f  [0.6572362780570984, 0.781000018119812]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A999D4C5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A999D4C5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for h in history:
    # Plot training & validation accuracy values
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Valiidation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Valiidation'], loc='upper left')
    plt.show()
